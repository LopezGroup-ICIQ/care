# %%
from torch import load

# %%
model_path = '../gnns/nouq_gnns/test_pkl'
params = load(model_path+'/GNN.pth')

# %%
params
# Out:
# OrderedDict([('input_layer.weight',
#               tensor([[-2.1327e-01, -1.3506e-01,  7.5746e-02,  ...,  8.7093e-02,
#                         1.0313e-01, -1.2583e-01],
#                       [-1.8931e-01, -1.3242e-01,  6.1940e-02,  ..., -1.8005e-01,
#                        -1.2415e-01, -2.0672e-01],
#                       [ 5.1081e-03, -1.7496e-02, -2.1220e-01,  ...,  9.9115e-02,
#                         1.6175e-01,  7.4355e-02],
#                       ...,
#                       [-3.9334e-02,  4.1576e-02, -4.5008e-02,  ..., -1.0198e-01,
#                         4.7148e-02,  1.6205e-01],
#                       [ 1.5387e-01,  7.4290e-02, -9.2726e-06,  ...,  1.6274e-01,
#                         2.0623e-01, -2.2401e-01],
#                       [ 8.1155e-02,  9.3502e-02, -5.3663e-03,  ..., -4.0876e-02,
#                        -5.3829e-02, -2.0547e-01]])),
#              ('conv_block.0.lin_l.weight',
# ...
